# %%
import matplotlib.pyplot as plt
x=[x for x in range(-10,11)]
y=[i**2 for i in x]
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-10, 10, 0.1)  # 0.1 간격으로 설정
y = x**2  # 각 x값에 대해 y값 계산

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('potential')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-1, 1, 0.1)  # 0.1 간격으로 설정
y = x**2 -(x-0.5)*np.sign(x-0.5) # 각 x값에 대해 y값 계산

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('potential')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xx=0
x = np.arange(-1, 1.05, 0.05)  # 0.1 간격으로 설정
y = x**2 -2*0.5*(x-xx)*np.sign(x-xx) # 각 x값에 대해 y값 계산

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('potential')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xx=0.5
x = np.arange(-1, 1.05, 0.05)  # 0.1 간격으로 설정
y = x**2 -2*0.5*(x-xx)*np.sign(x-xx) # 각 x값에 대해 y값 계산

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('potential')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# x 값 설정
x = np.arange(-1, 1.05, 0.05)

# xx 값의 범위 설정
xx_values = np.arange(-1, 1.5, 0.5)

# 컬러맵 설정 (각각의 xx에 대해 다른 색깔로 그래프)
colors = plt.cm.viridis(np.linspace(0, 1, len(xx_values)))

# 그래프 그리기
for i, xx in enumerate(xx_values):
    y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)
    plt.plot(x, y, label=f'xx={xx:.2f}', color=colors[i])

# 라벨 및 제목
plt.xlabel('x')
plt.ylabel('y')
plt.title('Potential Evolution with xx')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# x 값 설정
x = np.arange(-1.5, 1.55, 0.05)

# xx 값의 범위 설정
xx_values = np.arange(-1, 1.3, 0.5)

# 그래프 그리기
for xx in xx_values:
    # 새로운 창 열기
    plt.figure()
    
    # y 값 계산
    y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)
    
    # 그래프 그리기
    plt.plot(x, y, label=f'xx={xx:.2f}')
    
    # 라벨 및 제목
    plt.xlabel('X')
    plt.ylabel('Potential')
   
    plt.legend()
   
    
    # 그래프 표시 (개별 창으로)
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-1, 1.01, 0.01)

plt.figure(figsize=(10,8))

xx=0.
y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)
plt.plot(x, y, label=f'A', color='r')


xx=-.5
y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)


plt.plot(x, y, label=f'B', color='b')


plt.xlabel('X', fontsize=30)
plt.ylabel('Potential',fontsize=30)
plt.xticks([])
plt.yticks([])


plt.legend(fontsize = 20)
plt.gca().set_xticklabels([])
plt.gca().set_yticklabels([]) 
plt.scatter(-0.5, 0.28, color='g', s = 200)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-1, 1.01, 0.01)

plt.figure(figsize=(10,8))

xx=0.
y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)
plt.plot(x, y, label=f'A', color='r')
plt.scatter(-0.5, 0.28, color='g')
plt.axvline(x=0, color='red', linestyle='--', linewidth=1, label='Vertical Line')


xx=-.5
y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)
plt.plot(x, y, label=f'B', color='b')
plt.scatter(-0.5, 0.28, color='g', s = 200)
plt.axvline(x=0, color='red', linestyle='--', linewidth=1, label='Vertical Line')


plt.xlabel('X', fontsize=30)
plt.ylabel('Potential',fontsize=30)
plt.xticks([])
plt.yticks([])



plt.legend(fontsize = 20)
plt.gca().set_xticklabels([])
plt.gca().set_yticklabels([]) 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.axvline(x=5, color='red', linestyle='--', linewidth=1, label='Vertical Line')  # x=5 위치에 점선 추가
plt.xlabel('X Axis', fontsize=14)
plt.ylabel('Y Axis', fontsize=14)
plt.legend()
plt.show()

# %%
#   state1

import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-1, 1.01, 0.01)

plt.figure(figsize=(10,8))
plt.xlim(-1.2, 1.2)  # x축 범위 설정
plt.ylim(-0.8,0.8)  # y축 범위 설정
plt.xlabel('Displacement, X', fontsize=24)
plt.ylabel('Potential',fontsize=24)

# fig1
xx=0.
y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)
plt.plot(x, y, label=f'1', color='r')


# fig2
# xx=-.5
# y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)
# plt.plot(x, y, label=f'B', color='b')






plt.scatter(-0.5, -0.22, color='g', s = 200) # state point 추가

plt.text(0., -0.75, r'$\mathrm{\overline{X}}$', fontsize=24, ha='center', va='center') # 엑스바 텍스트 위치

plt.arrow(-0.1, -0.75, -0.2, 0.0, head_width=0.02, head_length=0.03, fc='black', ec='black')

#plt.axvline(x=-0.5, color='b', linestyle='--', linewidth=1)# 버티컬 라인 추가
plt.axvline(x=0, color='r', linestyle='--', linewidth=1) # 버티컬 라인 추가

plt.legend(fontsize = 20)
plt.gca().set_xticklabels([])
plt.gca().set_yticklabels([]) 
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#   state2

import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-1, 1.01, 0.01)

plt.figure(figsize=(10,8))
plt.xlim(-1.2, 1.2)  # x축 범위 설정
plt.ylim(-0.8, 0.8)  # y축 범위 설정
plt.xlabel('Displacement, X', fontsize=24)
plt.ylabel('Potential',fontsize=24)

xx=0.
y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)
plt.plot(x, y, label=f'1', color='r')


xx=-.5
y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)
plt.plot(x, y, label=f'2', color='b')






plt.scatter(-0.5, 0.28, color='g', s = 200) # state point 추가

plt.text(-0.5, -0.75, r'$\mathrm{\overline{X}}$', fontsize=24, ha='center', va='center') # 엑스바 텍스트 위치

#plt.arrow(-0.1, -0.75, -0.2, 0.0, head_width=0.02, head_length=0.03, fc='black', ec='black')
#plt.axvline(x=0, color='r', linestyle='--', linewidth=1) # 버티컬 라인 추가

plt.axvline(x=-0.5, color='b', linestyle='--', linewidth=1)# 버티컬 라인 추가


plt.legend(fontsize = 20)
plt.gca().set_xticklabels([])
plt.gca().set_yticklabels([]) 
plt.xticks([])
plt.yticks([])
plt.show()

# %%
# state 3
#   state2

import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-1, 1.01, 0.01)

plt.figure(figsize=(10,8))
plt.xlim(-1.2, 1.2)  # x축 범위 설정
plt.ylim(-0.8, 0.8)  # y축 범위 설정
plt.xlabel('Displacement, X', fontsize=24)
plt.ylabel('Potential',fontsize=24)

#xx=0.
# y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)
# plt.plot(x, y, label=f'A', color='r')
plt.axvline(x=-0.5, color='b', linestyle='--', linewidth=1)# 버티컬 라인 추가


xx=-.5
y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)
plt.plot(x, y, label=f'2', color='b')
#plt.axvline(x=0, color='r', linestyle='--', linewidth=1) # 버티컬 라인 추가





plt.scatter(0.5, -0.72, color='g', s = 200) # state point 추가

plt.text(-0.5, -0.75, r'$\mathrm{\overline{X}}$', fontsize=24, ha='center', va='center') # 엑스바 텍스트 위치

plt.arrow( -0.4, -0.75,0.5, 0, head_width=0.02, head_length=0.03, fc='black', ec='black')


plt.legend(fontsize = 20)
plt.gca().set_xticklabels([])
plt.gca().set_yticklabels([]) 
plt.xticks([])
plt.yticks([])
plt.show()

# %%
# state4


import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-1, 1.01, 0.01)

plt.figure(figsize=(10,8))
plt.xlim(-1.2, 1.2)  # x축 범위 설정
plt.ylim(-0.8, 0.8)  # y축 범위 설정
plt.xlabel('Displacement, X', fontsize=24)
plt.ylabel('Potential',fontsize=24)

xx=0.
y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)
plt.plot(x, y, label=f'3', color='r')



xx=.5
y = x**2 - 2 * 0.5 * (x - xx) * np.sign(x - xx)
plt.plot(x, y, label=f'4', color='b')






plt.scatter(0.5, -0.22, color='g', s = 200) # state point 추가

plt.text(0., -0.75, r'$\mathrm{\overline{X}}$', fontsize=24, ha='center', va='center') # 엑스바 텍스트 위치

plt.arrow(0.1, -0.75,0.3, 0, head_width=0.02, head_length=0.03, fc='black', ec='black')

plt.axvline(x=0.5, color='b', linestyle='--', linewidth=1)# 버티컬 라인 추가
plt.axvline(x=0, color='r', linestyle='--', linewidth=1) # 버티컬 라인 추가

plt.legend(fontsize = 20)
plt.gca().set_xticklabels([])
plt.gca().set_yticklabels([]) 
plt.xticks([])
plt.yticks([])
plt.show()
